# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np

# %% [markdown]
# SS=summer shallow;
# WS=winter shallow

# %%
SS=pd.read_csv("summershallow_B3.csv")
WS=pd.read_csv("wintershallow_B3.csv")

# %% [markdown]
# SD=summer deep ; WD= winter deep

# %%
SD=pd.read_csv("summerdeep_B1.csv")
WD=pd.read_csv("winterdeep_B1.csv")

# %%
A=SS.pressure
A1=SS.time
B=SS.temperature
C=SS.practical_salinity

# %% [markdown]
# z=depth [m]; z=h=P/(rho*g)

# %%
z=A/(1000*9.81)

# %%
D=WS.pressure
D2=WS.time
E=WS.temperature
F=WS.practical_salinity

# %%
z1=D/(1000*9.81)

# %%
G=SD.pressure
G2=SD.time
H=SD.temp
I=SD.practical_salinity

# %%
z2=G

# %%
J=WD.pressure
J2=WD.time
K=WD.temp
L=WD.practical_salinity

# %%
z3=J

# %%
ssp=1449.2+(4.6*B)-(0.055*B**2)+(0.00029*B**3)+(1.34-0.01*B)*(C-35)+(0.016*z)
sspmean=np.mean(ssp)
sspmean
# Out:
# 22837462955270.598

# %%
plt.plot(z,ssp)
plt.ylabel('ssp [m/s]')
plt.xlabel('depth [m]')
plt.title('depth vs ssp')
plt.axhline(y=sspmean, color='r', linestyle='-')

# %%
plt.plot(A1,z)
plt.ylabel('depth [m]')
plt.xlabel('time [s]')
plt.title('time vs depth')
# Out:
# Text(0.5, 1.0, 'time vs depth')

# %% [markdown]
# --------------------------------------------------------------------------------------------------

# %%
ssp1=1449.2+(4.6*E)-(0.055*E**2)+(0.00029*E**3)+(1.34-0.01*E)*(F-35)+(0.016*z1)
ssp1mean=np.mean(ssp1)
ssp1mean
# Out:
# 22936292154683.812

# %%
plt.plot(z1,ssp1)
plt.ylabel('ssp [m/s]')
plt.xlabel('depth [m]')
plt.title('depth vs ssp')
plt.axhline(y=ssp1mean, color='r', linestyle='-')

# %%
plt.plot(D2,z1)
plt.ylabel('depth [m]')
plt.xlabel('time [s]')
plt.title('time vs depth')
# Out:
# Text(0.5, 1.0, 'time vs depth')

# %% [markdown]
# --------------------------------------------------------------------------------------------------------

# %%
ssp2=1449.2+(4.6*H)-(0.055*H**2)+(0.00029*H**3)+(1.34-0.01*H)*(I-35)+(0.016*z2)
ssp2mean=np.mean(ssp2)
ssp2mean
# Out:
# 1484.0669448220804

# %%
plt.plot(z2,ssp2)
plt.ylabel('ssp [m/s]')
plt.xlabel('depth [m]')
plt.title('depth vs ssp')
plt.axhline(y=ssp2mean, color='r', linestyle='-')

# %%
plt.plot(G2,z2)
plt.ylabel('depth [m]')
plt.xlabel('time [s]')
plt.title('time vs depth')
# Out:
# Text(0.5, 1.0, 'time vs depth')

# %% [markdown]
# -----------------------------------------------------------------------------------------

# %%
ssp3=1449.2+(4.6*K)-(0.055*K**2)+(0.00029*K**3)+(1.34-0.01*K)*(L-35)+(0.016*z3)
ssp3mean=np.mean(ssp3)
ssp3mean
# Out:
# 1484.6212638099087

# %%
plt.plot(z3,ssp3)
plt.ylabel('ssp [m/s]')
plt.xlabel('depth [m]')
plt.title('depth vs ssp')
plt.axhline(y=ssp3mean, color='r', linestyle='-')

# %%
plt.plot(J2,z3)
plt.ylabel('depth [m]')
plt.xlabel('time [s]')
plt.title('time vs depth')
# Out:
# Text(0.5, 1.0, 'time vs depth')
